# %%
# !rm -rf * && git clone https://github.com/abdulmeLINK/transfer_learning
# Out:
# Cloning into 'transfer_learning'...
# remote: Enumerating objects: 152, done.
# remote: Counting objects: 100% (152/152), done.
# remote: Compressing objects: 100% (86/86), done.
# remote: Total 152 (delta 73), reused 128 (delta 50), pack-reused 0
# Receiving objects: 100% (152/152), 23.28 KiB | 11.64 MiB/s, done.
# Resolving deltas: 100% (73/73), done.

# %%
# !cd transfer_learning && git pull && chmod +x tests.sh && sh tests.sh
# Out:
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 4 (delta 2), reused 4 (delta 2), pack-reused 0
# Unpacking objects: 100% (4/4), 494 bytes | 494.00 KiB/s, done.
# From https://github.com/abdulmeLINK/transfer_learning
#    4332bd0..c32420e  main       -> origin/main
# Updating 4332bd0..c32420e
# Fast-forward
#  models/alexnet.py | 28 ++++++++++++++--------------
#  1 file changed, 14 insertions(+), 14 deletions(-)
# torch.Size([32, 256, 1, 2])
# torch.Size([32, 256, 6, 6])
# torch.Size([32, 256, 1, 2])
# torch.Size([32, 256, 6, 6])
# torch.Size([32, 256, 1, 2])
# torch.Size([32, 256, 6, 6])
# torch.Size([32, 256, 1, 2])
# torch.Size([32, 256, 6, 6])
# torch.Size([32, 256, 1, 2])
# torch.Size([32, 256, 6, 6])
# torch.Size([32, 256, 1, 2])
# torch.Size([32, 256, 6, 6])
# torch.Size([32, 256, 1, 2])
# torch.Size([32, 256, 6, 6])
# torch.Size([32, 256, 1, 2])
# torch.Size([32, 256, 6, 6])
# ...

# %%
# !cd transfer_learning && zip weights.zip weights/*.pt
# Out:
#   adding: weights/AlexNet_Scenario1.pt (deflated 1%)
#   adding: weights/AlexNet_Scenario2.pt (deflated 8%)
#   adding: weights/AlexNet_Scenario3.pt (deflated 8%)
#   adding: weights/AlexNet_Scenario4.pt (deflated 8%)
#   adding: weights/ResNet_Scenario1.pt (deflated 7%)
#   adding: weights/ResNet_Scenario2.pt (deflated 7%)
#   adding: weights/ResNet_Scenario3.pt (deflated 7%)
#   adding: weights/ResNet_Scenario4.pt (deflated 7%)
#   adding: weights/VGG_Scenario1.pt (deflated 7%)
#   adding: weights/VGG_Scenario2.pt (deflated 7%)
#   adding: weights/VGG_Scenario3.pt (deflated 7%)
#   adding: weights/VGG_Scenario4.pt (deflated 7%)
